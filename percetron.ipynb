# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#      Open    High     Low   Close    Volume  tommorow  Target
# 0  733.45  733.45  726.10  729.20  202628.0    730.60       1
# 1  733.80  734.85  728.00  730.60  554393.0    732.40       1
# 2  724.00  734.05  721.25  732.40  621031.0    719.65       0
# 3  725.00  725.00  718.40  719.65  299733.0    720.25       1
# 4  716.80  721.20  713.70  720.25  308155.0    715.30       0

# %%
df.drop(df.columns[[0,1,4,5]],axis=1,inplace=True)

# %%
df.head()
# Out:
#       Low   Close  Target
# 0  726.10  729.20       1
# 1  728.00  730.60       1
# 2  721.25  732.40       0
# 3  718.40  719.65       1
# 4  713.70  720.25       0

# %%
df2=df.head(500)
df2.shape
# Out:
# (500, 3)

# %%
import seaborn as sns

# %%
sns.scatterplot(x=df2['Low'], y=df2['Close'],hue=df2['Target'])
plt.show()

# %%
plt.scatter(df2['Low'],df2['Close'])

# %%
from sklearn.linear_model import Perceptron
p=Perceptron()

# %%
x = df2.iloc[:,0:2]
y = df2.iloc[:,-1]

print(y)
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 495    1
# 496    0
# 497    0
# 498    1
# 499    0
# Name: Target, Length: 500, dtype: int64

# %%
x.shape
# Out:
# (500, 2)

# %%
# p.fit(df[['Low','Close']],df['Target'])

p.fit(x,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 1164.55, -1886.35]])

# %%
p.intercept_
# Out:
# array([16.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.values,y.values,clf=p,legend=2)
# Out:
# C:\Users\Owner\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
